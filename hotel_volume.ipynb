# %%
import pandas as pd
import altair as alt

# %%
data = pd.read_csv('hotel_booking_2019_2020.csv')
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            1         74               2020            January
# 1  Resort Hotel            1         62               2020            January
# 2  Resort Hotel            1         62               2020            January
# 3  Resort Hotel            1         62               2020            January
# 4  Resort Hotel            1         71               2020            January
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                         1                          1
# 1                         1                          1
# 2                         1                          1
# 3                         1                          1
# 4                         1                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        1                     0       2  ...    No Deposit
# 1                        2                     2       2  ...    No Deposit
# 2                        2                     2       2  ...    No Deposit
# 3                        2                     2       2  ...    No Deposit
# 4                        2                     2       1  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type    adr  \
# 0    5.0     NaN                    0     Transient  57.60
# 1  240.0     NaN                    0     Transient  51.50
# 2  240.0     NaN                    0     Transient  51.50
# 3  240.0     NaN                    0     Transient  51.50
# 4  241.0     NaN                    0     Transient  32.22
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0            Canceled
# 1                            0                          1            Canceled
# 2                            0                          1            Canceled
# 3                            0                          1            Canceled
# 4                            0                          1            Canceled
#
#   reservation_status_date
# 0              10/20/2019
# 1               12/4/2019
# 2              11/11/2019
# 3               12/4/2019
# 4              10/29/2019
#
# [5 rows x 32 columns]

# %%
data_transform = data[['reservation_status_date','reservation_status']]
data_transform['reservation_status'] = (data['reservation_status'] == 'Canceled').astype(int)
data_transform['reservation_status_date'] = pd.to_datetime(data_transform['reservation_status_date'])
data_transform.head()
# Out:
# C:\Users\Quiet\AppData\Local\Temp\ipykernel_6544\1118864487.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_transform['reservation_status'] = (data['reservation_status'] == 'Canceled').astype(int)
# C:\Users\Quiet\AppData\Local\Temp\ipykernel_6544\1118864487.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_transform['reservation_status_date'] = pd.to_datetime(data_transform['reservation_status_date'])
#   reservation_status_date  reservation_status
# 0              2019-10-20                   1
# 1              2019-12-04                   1
# 2              2019-11-11                   1
# 3              2019-12-04                   1
# 4              2019-10-29                   1

# %%
data_final = data_transform.groupby('reservation_status_date').count().reset_index()
# Out:
#   reservation_status_date  reservation_status
# 0              2018-10-21                 221
# 1              2019-01-17                   2
# 2              2019-02-02                   3
# 3              2019-03-17                   1
# 4              2019-03-20                   1

# %%
line_chart = alt.Chart(data_final).mark_line().encode(
    x=alt.X('reservation_status_date:T',title='Date'),
    y=alt.Y('reservation_status:Q',title='Bookings'),
)

line_chart
# Out:
# alt.Chart(...)
